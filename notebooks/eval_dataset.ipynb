# %% [markdown]
# ## Evaluation Dataset

# %%
import pandas as pd

# %%
df = pd.read_json("../datasets/checker_eval/checker_eval.json")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 20 non-null     int64
#  1   name               20 non-null     str
#  2   category           20 non-null     str
#  3   polarity           20 non-null     str
#  4   domain             20 non-null     str
#  5   expected_label     20 non-null     str
#  6   expected_status    20 non-null     str
#  7   expected_category  10 non-null     str
#  8   description        20 non-null     str
#  9   flaw               20 non-null     str
#  10  intent             20 non-null     object
#  11  original           20 non-null     object
#  12  optimized          20 non-null     object
# dtypes: int64(1), object(3), str(9)
# memory usage: 2.2+ KB

# %%
df[['category', 'polarity', 'domain']].value_counts()
# Out:
# category                polarity  domain
# correctness             pos       e-commerce checkout          1
#                         neg       library catalog search       1
#                         pos       flight booking search        1
#                         neg       food delivery order stats    1
# safety                  pos       blogging CMS                 1
#                         neg       social media feed            1
#                         pos       warehouse inventory          1
#                         neg       ride-sharing dispatch        1
# regression              pos       movie streaming catalog      1
#                         neg       job board                    1
#                         pos       hotel booking                1
#                         neg       event ticketing              1
# completeness            pos       pharmacy refill service      1
#                         neg       gym membership service       1
# ...

# %%
pd.set_option('display.max_colwidth', None)

df.head()
# Out:
#    id                       name     category polarity                     domain expected_label expected_status expected_category                                                                                                                                                                                                                                                                                    description                                                                                                                                                                                                                                                                                                                                                                                                      flaw                                                                                                                                                                                           
# ...

# %%
df.to_csv('eval_dataset.csv', index=False)
